# %% [markdown]
# # Test

# %%
def add_numbers(num_1, num_2):
    '''
    Adds 2 numbers
    >>> add_numbers(2, 3)
    5
    
    '''
    return num_1 + num_2

# %%
help(add_numbers)
# Out:
# Help on function add_numbers in module __main__:
#
# add_numbers(num_1, num_2)
#     Adds 2 numbers
#     >>> add_numbers(2, 3)
#     5

# %%
import doctest

# %%
doctest.testmod(verbose=True)
# Out:
# Trying:
#     add_numbers(2, 3)
# Expecting:
#     5
# ok
# 1 item had no tests:
#     __main__
# 1 item passed all tests:
#    1 test in __main__.add_numbers
# 1 test in 2 items.
# 1 passed.
# Test passed.
# TestResults(failed=0, attempted=1)

# %%
'test using pytest'
# Out:
# 'test using pytest'
